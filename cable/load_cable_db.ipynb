# %%
import pandas as pd

# %%
filename = u'./cable_db.csv'

cable_db = pd.read_csv( filename, decimal=',', sep=';')

# %%
cable_db
# Out:
#                    Cstring      D     d  TLO  THI  TCDRMAX      RLO      RHI  \
# 0  400 mm2 DRAKE 26/7 ACSR  28.12  4.44   25   75      100  0.07284  0.08689
# 1                   LA-180  17.50  2.50    5   85      100  0.21993  0.25197
# 2                   LA-280  21.80  3.44    5   85      100  0.13384  0.15707
#
#   EMISS ABSORP  HNH HEATOUT HEATCORE TotalS
# 0   0.5    0.5    3  1139.5    351.7  486.6
# 1   0.5    0.5    2  379.81   128.16    NaN
# 2   0.5    0.5    2  623.22   147.22    NaN

# %%
cableid = u'LA-280'
#cableid = u'cc'

cablex = cable_db[ cable_db[ 'Cstring'] == cableid]

print(cablex)

print( len(cablex))
# Out:
#   Cstring      D     d  TLO  THI  TCDRMAX      RLO      RHI EMISS ABSORP  HNH  \
# 2  LA-280  21.80  3.44    5   85      100  0.13384  0.15707   0.5    0.5    2
#
#   HEATOUT HEATCORE TotalS
# 2  623.22   147.22    NaN
# 1
